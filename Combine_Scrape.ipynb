# %% [markdown]
# # Import Libraries

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Scrape Data

# %% [markdown]
# Create list of player combine data urls to scrape

# %%
combine_urls = []
for year in range(2014, 2019):
    combine_urls.append(f'https://www.nbadraft.net/{year}-nba-draft-combine-measurements/')

# %% [markdown]
# Create empty list for player combine data

# %%
combine_data = []

# %% [markdown]
# Scrape combine stat urls and crate beautifulsoup html soups for each url

# %%
for url in combine_urls:
    print(url)
    headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
    response = requests.get(url, headers = headers, timeout=5)
    soup = BeautifulSoup(response.content, 'html.parser')
    div = soup.find('div', {'class' : 'entry-content'})
    table = div.find('table')
    body = table.find_all('tbody')[1]
    players = body.find_all('tr')
    for player in players:
        player_list = []
        player_list.append(url.split('-')[0][-4:])
        for stat in player.find_all('td'):
            player_list.append(stat.text)
        combine_data.append(player_list)
# Out:
# https://www.nbadraft.net/2014-nba-draft-combine-measurements/
# https://www.nbadraft.net/2015-nba-draft-combine-measurements/
# https://www.nbadraft.net/2016-nba-draft-combine-measurements/
# https://www.nbadraft.net/2017-nba-draft-combine-measurements/
# https://www.nbadraft.net/2018-nba-draft-combine-measurements/

# %%
len(combine_data)
# Out:
# 321

# %%
for item in combine_data:
    print(item)
# Out:
# ['2014', 'Jordan Adams SG', '6′ 3.50” ‘', '6′ 4.75”', '208.8', '6′ 10.00′', '8′ 6.00”', '10.80', '8.50', '7.50']
# ['2014', 'Kyle Anderson SF', '6′ 7.50”', '6′ 8.50”', '230.1', '7′ 2.75′', '8′ 11.50”', '13.35', '8.25', '8.75']
# ['2014', 'Thanasis Antetokounmpo SF', '6′ 5.25”', '6′ 6.25”', '205.2', '7′ 0.00”', '8′ 8.50”', '6.05', '9.00', '9.75']
# ['2014', 'Isaiah Austin PF-C', '6′ 11.50”', '7′ 0.50”', '219.5', '7′ 4.50”', '9′ 4.50”', '7.50', '8.75', '8.75']
# ['2014', 'Jordan Bachynski PF-C', '7′ 1.25”', '7′ 2.00”', '254.1', '7′ 4.00”', '9′ 0.50”', '7.50', '9.25', '10.00']
# ['2014', 'Cameron Bairstow PF-C', '6′ 8.75”', '6′ 9.75”', '252.4', '7′ 0.75”', '8′ 11.00”', '8.70', '8.75', '9.00']
# ['2014', 'Khem Birch PF-C', '6′ 7.50”', '6′ 9.25”', '208.8', '7′ 1.00”', '8′ 11.00”', '6.00', '9.00', '8.50']
# ['2014', 'Markel Brown SG', '6′ 2.50”', '6′ 3.50”', '184.4', '6′ 8.75”', '8′ 4.00”', '4.20', '8.25', '9.75']
# ...

# %%
# Out:
# <div class="entry-content"><table border="1" width="100%"><tbody><tr><td bgcolor="#666666" width="20%"><b>Player</b></td><td bgcolor="#666666" width="8%"><b>Height w/o Shoes </b></td><td bgcolor="#666666" width="11%"><b>Height w/ Shoes </b></td><td bgcolor="#666666" width="11%"><b>Weight</b></td><td bgcolor="#666666" width="11%"><b>Wingspan</b></td><td bgcolor="#666666" width="11%"><b>Standing Reach </b></td><td bgcolor="#666666" width="11%"><b><br/> Body Fat % </b></td><td bgcolor="#666666" width="8%"><b>Hand Length<br/> </b></td><td bgcolor="#666666" width="9%"><b>Hand Width</b></td></tr></tbody><tbody><tr><td width="20%"><a class="link-player" href="https://www.nbadraft.net/players/ron-baker/">Ron Baker</a> SG</td><td width="9%">6′ 3.25”</td><td width="8%">6′ 4.25”</td><td width="11%">212.4</td><td width="11%">6′ 9.75”</td><td width="8%">8′ 1.5”</td><td width="14%">7.85%</td><td width="11%">8.75</td><td width="8%">9.50</td></tr><tr><td bgcolor="#cccccc" width="20%"><a class="link-
# ...

# %%
response
# Out:
# <Response [200]>

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
driver_path = '/Users/jesseblant/Documents/Stocks/Other/Overview/chromedriver'
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
driver = webdriver.Chrome(options=options, executable_path=driver_path)
